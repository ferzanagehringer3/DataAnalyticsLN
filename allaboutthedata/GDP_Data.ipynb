# %% [markdown]
# create a csv file with GDP data to combine in our "Data_Preparation" notebook

# %% [markdown]
# ### Libraries and settings

# %%
import requests
import pandas as pd

# %% [markdown]
# With this code we can fetch the data from the worldbank api. Gross Domestic Product (GDP) represents the total monetary value of all goods and services produced within a country's borders in a specific time period (usually annually). It’s often used to:
# Measure a country’s economic health.
# Understand living standards.
# Compare economies globally.
#
# For our project, GDP data can enrich our refugee dataset by providing additional insights, such as:
#
# Whether higher GDP correlates with more refugees being accepted.

# %%
# Define parameters
countries = ["USA", "DEU", "FRA", "CHE", "SWE", "GBR", "GRC", "ITA", "ESP", "PRT", "TUR"]

years = range(1998, 2025)
indicator = "NY.GDP.MKTP.CD"  # GDP (current US$)

# Storage for results
gdp_data = []

try:
    print("Fetching GDP data from World Bank API...")
    for country in countries:
        for year in years:
            url = f"https://api.worldbank.org/v2/country/{country}/indicator/{indicator}"
            params = {
                "date": year,
                "format": "json"
            }
            
            response = requests.get(url, params=params)
            if response.status_code != 200:
                print(f"Failed to fetch data for {country} in {year}. Status code: {response.status_code}")
                continue
            
            data = response.json()
            if len(data) > 1 and data[1] is not None:
                for entry in data[1]:
                    gdp_data.append({
                        "country_code": entry['country']['id'],
                        "country_name": entry['country']['value'],
                        "year": int(entry['date']),
                        "gdp": entry['value']
                    })
            print(f"Fetched GDP data for {country} in {year}")

    # Convert to DataFrame
    gdp_df = pd.DataFrame(gdp_data)
    gdp_df.to_csv('gdp_data_1998_2024.csv', index=False)
    print("✅ GDP data successfully saved to 'gdp_data_1998_2024.csv'")
    
except Exception as e:
    print(f"❌ Error fetching GDP data: {e}")
# Out:
# Fetching GDP data from World Bank API...
# Fetched GDP data for USA in 1998
# Fetched GDP data for USA in 1999
# Fetched GDP data for USA in 2000
# Fetched GDP data for USA in 2001
# Fetched GDP data for USA in 2002
# Fetched GDP data for USA in 2003
# Fetched GDP data for USA in 2004
# Fetched GDP data for USA in 2005
# Fetched GDP data for USA in 2006
# Fetched GDP data for USA in 2007
# Fetched GDP data for USA in 2008
# Fetched GDP data for USA in 2009
# Fetched GDP data for USA in 2010
# Fetched GDP data for USA in 2011
# Fetched GDP data for USA in 2012
# Fetched GDP data for USA in 2013
# Fetched GDP data for USA in 2014
# Fetched GDP data for USA in 2015
# Fetched GDP data for USA in 2016
# Fetched GDP data for USA in 2017
# Fetched GDP data for USA in 2018
# Fetched GDP data for USA in 2019
# Fetched GDP data for USA in 2020
# Fetched GDP data for USA in 2021
# Fetched GDP data for USA in 2022
# Fetched GDP data for USA in 2023
# Fetched GDP data for USA in 2024
# Fetched GDP data for DEU in 1998
# Fetched GDP data for DEU in 1999
# Fetched GDP data for DEU in 2000
# Fetched GDP data for DEU in 2001
# Fetched GDP data for DEU in 2002
# Fetched GDP data for DEU in 2003
# Fetched GDP data for DEU in 2004
# Fetched GDP data for DEU in 2005
# Fetched GDP data for DEU in 2006
# Fetched GDP data for DEU in 2007
# Fetched GDP data for DEU in 2008
# Fetched GDP data for DEU in 2009
# Fetched GDP data for DEU in 2010
# Fetched GDP data for DEU in 2011
# Fetched GDP data for DEU in 2012
# Fetched GDP data for DEU in 2013
# Fetched GDP data for DEU in 2014
# Fetched GDP data for DEU in 2015
# Fetched GDP data for DEU in 2016
# Fetched GDP data for DEU in 2017
# Fetched GDP data for DEU in 2018
# Fetched GDP data for DEU in 2019
# Fetched GDP data for DEU in 2020
# Fetched GDP data for DEU in 2021
# Fetched GDP data for DEU in 2022
# Fetched GDP data for DEU in 2023
# Fetched GDP data for DEU in 2024
# Fetched GDP data for FRA in 1998
# Fetched GDP data for FRA in 1999
# Fetched GDP data for FRA in 2000
# Fetched GDP data for FRA in 2001
# Fetched GDP data for FRA in 2002
# Fetched GDP data for FRA in 2003
# Fetched GDP data for FRA in 2004
# Fetched GDP data for FRA in 2005
# Fetched GDP data for FRA in 2006
# Fetched GDP data for FRA in 2007
# Fetched GDP data for FRA in 2008
# Fetched GDP data for FRA in 2009
# Fetched GDP data for FRA in 2010
# Fetched GDP data for FRA in 2011
# Fetched GDP data for FRA in 2012
# Fetched GDP data for FRA in 2013
# Fetched GDP data for FRA in 2014
# Fetched GDP data for FRA in 2015
# Fetched GDP data for FRA in 2016
# Fetched GDP data for FRA in 2017
# Fetched GDP data for FRA in 2018
# Fetched GDP data for FRA in 2019
# Fetched GDP data for FRA in 2020
# Fetched GDP data for FRA in 2021
# Fetched GDP data for FRA in 2022
# Fetched GDP data for FRA in 2023
# Fetched GDP data for FRA in 2024
# Fetched GDP data for CHE in 1998
# Fetched GDP data for CHE in 1999
# Fetched GDP data for CHE in 2000
# Fetched GDP data for CHE in 2001
# Fetched GDP data for CHE in 2002
# Fetched GDP data for CHE in 2003
# Fetched GDP data for CHE in 2004
# Fetched GDP data for CHE in 2005
# Fetched GDP data for CHE in 2006
# Fetched GDP data for CHE in 2007
# Fetched GDP data for CHE in 2008
# Fetched GDP data for CHE in 2009
# Fetched GDP data for CHE in 2010
# Fetched GDP data for CHE in 2011
# Fetched GDP data for CHE in 2012
# Fetched GDP data for CHE in 2013
# Fetched GDP data for CHE in 2014
# Fetched GDP data for CHE in 2015
# Fetched GDP data for CHE in 2016
# Fetched GDP data for CHE in 2017
# Fetched GDP data for CHE in 2018
# Fetched GDP data for CHE in 2019
# Fetched GDP data for CHE in 2020
# Fetched GDP data for CHE in 2021
# Fetched GDP data for CHE in 2022
# Fetched GDP data for CHE in 2023
# Fetched GDP data for CHE in 2024
# Fetched GDP data for SWE in 1998
# Fetched GDP data for SWE in 1999
# Fetched GDP data for SWE in 2000
# Fetched GDP data for SWE in 2001
# Fetched GDP data for SWE in 2002
# Fetched GDP data for SWE in 2003
# Fetched GDP data for SWE in 2004
# Fetched GDP data for SWE in 2005
# Fetched GDP data for SWE in 2006
# Fetched GDP data for SWE in 2007
# Fetched GDP data for SWE in 2008
# Fetched GDP data for SWE in 2009
# Fetched GDP data for SWE in 2010
# Fetched GDP data for SWE in 2011
# Fetched GDP data for SWE in 2012
# Fetched GDP data for SWE in 2013
# Fetched GDP data for SWE in 2014
# Fetched GDP data for SWE in 2015
# Fetched GDP data for SWE in 2016
# Fetched GDP data for SWE in 2017
# Fetched GDP data for SWE in 2018
# Fetched GDP data for SWE in 2019
# Fetched GDP data for SWE in 2020
# Fetched GDP data for SWE in 2021
# Fetched GDP data for SWE in 2022
# Fetched GDP data for SWE in 2023
# Fetched GDP data for SWE in 2024
# Fetched GDP data for GBR in 1998
# Fetched GDP data for GBR in 1999
# Fetched GDP data for GBR in 2000
# Fetched GDP data for GBR in 2001
# Fetched GDP data for GBR in 2002
# Fetched GDP data for GBR in 2003
# Fetched GDP data for GBR in 2004
# Fetched GDP data for GBR in 2005
# Fetched GDP data for GBR in 2006
# Fetched GDP data for GBR in 2007
# Fetched GDP data for GBR in 2008
# Fetched GDP data for GBR in 2009
# Fetched GDP data for GBR in 2010
# Fetched GDP data for GBR in 2011
# Fetched GDP data for GBR in 2012
# Fetched GDP data for GBR in 2013
# Fetched GDP data for GBR in 2014
# Fetched GDP data for GBR in 2015
# Fetched GDP data for GBR in 2016
# Fetched GDP data for GBR in 2017
# Fetched GDP data for GBR in 2018
# Fetched GDP data for GBR in 2019
# Fetched GDP data for GBR in 2020
# Fetched GDP data for GBR in 2021
# Fetched GDP data for GBR in 2022
# Fetched GDP data for GBR in 2023
# Fetched GDP data for GBR in 2024
# Fetched GDP data for GRC in 1998
# Fetched GDP data for GRC in 1999
# Fetched GDP data for GRC in 2000
# Fetched GDP data for GRC in 2001
# Fetched GDP data for GRC in 2002
# Fetched GDP data for GRC in 2003
# Fetched GDP data for GRC in 2004
# Fetched GDP data for GRC in 2005
# Fetched GDP data for GRC in 2006
# Fetched GDP data for GRC in 2007
# Fetched GDP data for GRC in 2008
# Fetched GDP data for GRC in 2009
# Fetched GDP data for GRC in 2010
# Fetched GDP data for GRC in 2011
# Fetched GDP data for GRC in 2012
# Fetched GDP data for GRC in 2013
# Fetched GDP data for GRC in 2014
# Fetched GDP data for GRC in 2015
# Fetched GDP data for GRC in 2016
# Fetched GDP data for GRC in 2017
# Fetched GDP data for GRC in 2018
# Fetched GDP data for GRC in 2019
# Fetched GDP data for GRC in 2020
# Fetched GDP data for GRC in 2021
# Fetched GDP data for GRC in 2022
# Fetched GDP data for GRC in 2023
# Fetched GDP data for GRC in 2024
# Fetched GDP data for ITA in 1998
# Fetched GDP data for ITA in 1999
# Fetched GDP data for ITA in 2000
# Fetched GDP data for ITA in 2001
# Fetched GDP data for ITA in 2002
# Fetched GDP data for ITA in 2003
# Fetched GDP data for ITA in 2004
# Fetched GDP data for ITA in 2005
# Fetched GDP data for ITA in 2006
# Fetched GDP data for ITA in 2007
# Fetched GDP data for ITA in 2008
# Fetched GDP data for ITA in 2009
# Fetched GDP data for ITA in 2010
# Fetched GDP data for ITA in 2011
# Fetched GDP data for ITA in 2012
# Fetched GDP data for ITA in 2013
# Fetched GDP data for ITA in 2014
# Fetched GDP data for ITA in 2015
# Fetched GDP data for ITA in 2016
# Fetched GDP data for ITA in 2017
# Fetched GDP data for ITA in 2018
# Fetched GDP data for ITA in 2019
# Fetched GDP data for ITA in 2020
# Fetched GDP data for ITA in 2021
# Fetched GDP data for ITA in 2022
# Fetched GDP data for ITA in 2023
# Fetched GDP data for ITA in 2024
# Fetched GDP data for ESP in 1998
# Fetched GDP data for ESP in 1999
# Fetched GDP data for ESP in 2000
# Fetched GDP data for ESP in 2001
# Fetched GDP data for ESP in 2002
# Fetched GDP data for ESP in 2003
# Fetched GDP data for ESP in 2004
# Fetched GDP data for ESP in 2005
# Fetched GDP data for ESP in 2006
# Fetched GDP data for ESP in 2007
# Fetched GDP data for ESP in 2008
# Fetched GDP data for ESP in 2009
# Fetched GDP data for ESP in 2010
# Fetched GDP data for ESP in 2011
# Fetched GDP data for ESP in 2012
# Fetched GDP data for ESP in 2013
# Fetched GDP data for ESP in 2014
# Fetched GDP data for ESP in 2015
# Fetched GDP data for ESP in 2016
# Fetched GDP data for ESP in 2017
# Fetched GDP data for ESP in 2018
# Fetched GDP data for ESP in 2019
# Fetched GDP data for ESP in 2020
# Fetched GDP data for ESP in 2021
# Fetched GDP data for ESP in 2022
# Fetched GDP data for ESP in 2023
# Fetched GDP data for ESP in 2024
# Fetched GDP data for PRT in 1998
# Fetched GDP data for PRT in 1999
# Fetched GDP data for PRT in 2000
# Fetched GDP data for PRT in 2001
# Fetched GDP data for PRT in 2002
# Fetched GDP data for PRT in 2003
# Fetched GDP data for PRT in 2004
# Fetched GDP data for PRT in 2005
# Fetched GDP data for PRT in 2006
# Fetched GDP data for PRT in 2007
# Fetched GDP data for PRT in 2008
# Fetched GDP data for PRT in 2009
# Fetched GDP data for PRT in 2010
# Fetched GDP data for PRT in 2011
# Fetched GDP data for PRT in 2012
# Fetched GDP data for PRT in 2013
# Fetched GDP data for PRT in 2014
# Fetched GDP data for PRT in 2015
# Fetched GDP data for PRT in 2016
# Fetched GDP data for PRT in 2017
# Fetched GDP data for PRT in 2018
# Fetched GDP data for PRT in 2019
# Fetched GDP data for PRT in 2020
# Fetched GDP data for PRT in 2021
# Fetched GDP data for PRT in 2022
# Fetched GDP data for PRT in 2023
# Fetched GDP data for PRT in 2024
# Fetched GDP data for TUR in 1998
# Fetched GDP data for TUR in 1999
# Fetched GDP data for TUR in 2000
# Fetched GDP data for TUR in 2001
# Fetched GDP data for TUR in 2002
# Fetched GDP data for TUR in 2003
# Fetched GDP data for TUR in 2004
# Fetched GDP data for TUR in 2005
# Fetched GDP data for TUR in 2006
# Fetched GDP data for TUR in 2007
# Fetched GDP data for TUR in 2008
# Fetched GDP data for TUR in 2009
# Fetched GDP data for TUR in 2010
# Fetched GDP data for TUR in 2011
# Fetched GDP data for TUR in 2012
# Fetched GDP data for TUR in 2013
# Fetched GDP data for TUR in 2014
# Fetched GDP data for TUR in 2015
# Fetched GDP data for TUR in 2016
# Fetched GDP data for TUR in 2017
# Fetched GDP data for TUR in 2018
# Fetched GDP data for TUR in 2019
# Fetched GDP data for TUR in 2020
# Fetched GDP data for TUR in 2021
# Fetched GDP data for TUR in 2022
# Fetched GDP data for TUR in 2023
# Fetched GDP data for TUR in 2024
# ✅ GDP data successfully saved to 'gdp_data_1998_2024.csv'
